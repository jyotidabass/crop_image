# %% [markdown]
# <a href="https://colab.research.google.com/github/jyotidabass/crop_image/blob/main/crop_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image 
 
  
img = Image.open(r"/content/drive/MyDrive/flower_photos/roses/22679076_bdb4c24401_m.jpg") 
 
 
left = 0
top = 50
right = 510
bottom = 292
 
  
img_res = img.crop((left, top, right, bottom)) 
 
 
img_res.show() 
plt.imshow(img_res)
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
